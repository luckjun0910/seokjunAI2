# %% [markdown]
# <a href="https://colab.research.google.com/github/luckjun0910/seokjunAI2/blob/main/boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
#과거의 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/luckjun0910/seokjunAI2/main/boston%20(1).csv'
보스턴 = pd.read_csv(파일경로)
print(보스턴.columns)
보스턴.head()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#독립변수, 종속변수 분리하기
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 'rm','age','dis','rad', 'tax',
         'ptratio','b','lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
#2. 모델의 구조를 만들기
x = tf.keras.layers.Input(shape=[13])
y = tf.keras.layers.Dense(1)(x)
model = tf.keras.models.Model(x,y)
model.compile(loss='mse')

# %%
#3. 데이터로 모델을학습(fit)함
model.fit(독립,종속, epochs=1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5809
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.7181
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5533
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5285
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5733
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.3421
# Epoch 7/10
# 16/16 [==============================] - 0s 3ms/step - loss: 26.6043
# Epoch 8/10
# 16/16 [==============================] - 0s 3ms/step - loss: 25.9938
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5486
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.9497

# %%
#모델을 이용
print(model.predict(독립[5:10]))
#종속 변수 확인
print(종속[5:10])
# Out:
# 1/1 [==============================] - 0s 92ms/step
# [[26.376324]
#  [21.212023]
#  [18.123869]
#  [ 9.499677]
#  [17.763119]]
#    medv
# 5  28.7
# 6  22.9
# 7  27.1
# 8  16.5
# 9  18.9

# %%
#모델의 수식 확인
print(model.get_weights())
# Out:
# [array([[-0.08989495],
#        [ 0.07295885],
#        [-0.0578682 ],
#        [ 3.4700365 ],
#        [ 1.4813434 ],
#        [ 3.9067647 ],
#        [ 0.01779986],
#        [-0.85389584],
#        [ 0.14717963],
#        [-0.0093755 ],
#        [ 0.01325629],
#        [ 0.01659435],
#        [-0.5836048 ]], dtype=float32), array([2.7301857], dtype=float32)]
